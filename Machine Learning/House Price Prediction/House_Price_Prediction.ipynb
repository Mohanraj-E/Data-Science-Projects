# %%
import numpy as np
import pandas as pd

# %%
House_DF=pd.read_csv(r"C:\Users\MOHANRAJ\Desktop\Projects\Machine Learning\House Price Prediction\House_Data.csv")
House_DF.head()
# Out:
#    Unnamed: 0  Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0           0   1          60         3         65.0     8450       1      1
# 1           1   2          20         3         80.0     9600       1      1
# 2           2   3          60         3         68.0    11250       1      1
# 3           3   4          70         3         60.0     9550       1      1
# 4           4   5          60         3         84.0    14260       1      1
#
#    LotShape  LandContour  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0         3            3  ...         0       1      3            3        0
# 1         3            3  ...         0       1      3            3        0
# 2         0            3  ...         0       1      3            3        0
# 3         0            3  ...         0       1      3            3        0
# 4         0            3  ...         0       1      3            3        0
#
# ...

# %%
del House_DF[House_DF.columns[0]]
House_DF
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1          60         3         65.0     8450       1      1
# 1        2          20         3         80.0     9600       1      1
# 2        3          60         3         68.0    11250       1      1
# 3        4          70         3         60.0     9550       1      1
# 4        5          60         3         84.0    14260       1      1
# ...    ...         ...       ...          ...      ...     ...    ...
# 1455  1456          60         3         62.0     7917       1      1
# 1456  1457          20         3         85.0    13175       1      1
# 1457  1458          70         3         66.0     9042       1      1
# 1458  1459          20         3         68.0     9717       1      1
# 1459  1460          20         3         75.0     9937       1      1
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
House_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int64
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int64
#  8   LandContour    1460 non-null   int64
#  9   Utilities      1460 non-null   int64
#  10  LotConfig      1460 non-null   int64
#  11  LandSlope      1460 non-null   int64
#  12  Neighborhood   1460 non-null   int64
#  13  Condition1     1460 non-null   int64
#  14  Condition2     1460 non-null   int64
#  15  BldgType       1460 non-null   int64
#  16  HouseStyle     1460 non-null   int64
#  17  OverallQual    1460 non-null   int64
# ...

# %%
House_DF.isnull().sum().head(40)
# Out:
# Id              0
# MSSubClass      0
# MSZoning        0
# LotFrontage     0
# LotArea         0
# Street          0
# Alley           0
# LotShape        0
# LandContour     0
# Utilities       0
# LotConfig       0
# LandSlope       0
# Neighborhood    0
# Condition1      0
# Condition2      0
# BldgType        0
# HouseStyle      0
# OverallQual     0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# RoofStyle       0
# RoofMatl        0
# Exterior1st     0
# Exterior2nd     0
# MasVnrType      0
# MasVnrArea      8
# ExterQual       0
# ExterCond       0
# Foundation      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinSF1      0
# BsmtFinType2    0
# BsmtFinSF2      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# Heating         0
# dtype: int64

# %%
House_DF.isnull().sum().tail(40)
# Out:
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# PoolQC           0
# Fence            0
# MiscFeature      0
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# dtype: int64

# %%
House_DF["PoolQC"].value_counts()
House_DF["Fence"].value_counts()
House_DF["GarageYrBlt"].mean()
House_DF["GarageFinish"].value_counts()
House_DF["MiscFeature"].value_counts()
House_DF["GarageQual"].value_counts()
House_DF["GarageCond"].value_counts()
House_DF["GarageType"].value_counts()
House_DF["FireplaceQu"].value_counts()
House_DF["Electrical"].value_counts()
# Out:
# 4    1334
# 0      94
# 1      27
# 2       3
# 3       2
# Name: Electrical, dtype: int64

# %%
House_DF["PoolQC"]=House_DF["PoolQC"].fillna('Fa')
House_DF["MiscFeature"]=House_DF["MiscFeature"].fillna('TenC')
House_DF["Fence"]=House_DF["Fence"].fillna('MnWw')
House_DF["GarageQual"]=House_DF["GarageQual"].fillna("Gd")
House_DF["GarageYrBlt"]=House_DF["GarageYrBlt"].fillna('1978.50')
House_DF["GarageFinish"]=House_DF["GarageFinish"].fillna('Fin')
House_DF["GarageCond"]=House_DF["GarageCond"].fillna('Ex')
House_DF["GarageType"]=House_DF["GarageType"].fillna('2Types')
House_DF["FireplaceQu"]=House_DF["FireplaceQu"].fillna('Po')
House_DF["Electrical"]=House_DF["Electrical"].fillna('Mix')

# %%
from sklearn.preprocessing import LabelEncoder
l1=LabelEncoder()

House_DF["MSZoning"]=l1.fit_transform(House_DF["MSZoning"])
House_DF["Street"]=l1.fit_transform(House_DF["Street"])
House_DF["Alley"]=l1.fit_transform(House_DF["Alley"])
House_DF["LotShape"]=l1.fit_transform(House_DF["LotShape"])
House_DF["LandContour"]=l1.fit_transform(House_DF["LandContour"])
House_DF["Utilities"]=l1.fit_transform(House_DF["Utilities"])
House_DF["LotConfig"]=l1.fit_transform(House_DF["LotConfig"])
House_DF["Neighborhood"]=l1.fit_transform(House_DF["Neighborhood"])
House_DF["LandSlope"]=l1.fit_transform(House_DF["LandSlope"])
House_DF["Condition1"]=l1.fit_transform(House_DF["Condition1"])
House_DF["Condition2"]=l1.fit_transform(House_DF["Condition2"])
House_DF["BldgType"]=l1.fit_transform(House_DF["BldgType"])
House_DF["HouseStyle"]=l1.fit_transform(House_DF["HouseStyle"])
House_DF["RoofStyle"]=l1.fit_transform(House_DF["RoofStyle"])
House_DF["RoofMatl"]=l1.fit_transform(House_DF["RoofMatl"])
House_DF["Exterior1st"]=l1.fit_transform(House_DF["Exterior1st"])
House_DF["Exterior2nd"]=l1.fit_transform(House_DF["Exterior2nd"])
House_DF["MasVnrType"]=l1.fit_transform(House_DF["MasVnrType"])
House_DF["ExterQual"]=l1.fit_transform(House_DF["ExterQual"])
House_DF["ExterCond"]=l1.fit_transform(House_DF["ExterCond"])
House_DF["BsmtExposure"]=l1.fit_transform(House_DF["BsmtExposure"])
House_DF["Foundation"]=l1.fit_transform(House_DF["Foundation"])
House_DF["BsmtQual"]=l1.fit_transform(House_DF["BsmtQual"])
House_DF["BsmtCond"]=l1.fit_transform(House_DF["BsmtCond"])
House_DF["BsmtFinType1"]=l1.fit_transform(House_DF["BsmtFinType1"])
House_DF["BsmtFinType2"]=l1.fit_transform(House_DF["BsmtFinType2"])
House_DF["Heating"]=l1.fit_transform(House_DF["Heating"])
House_DF["HeatingQC"]=l1.fit_transform(House_DF["HeatingQC"])
House_DF["CentralAir"]=l1.fit_transform(House_DF["CentralAir"])
House_DF["Electrical"]=l1.fit_transform(House_DF["Electrical"])
House_DF["KitchenQual"]=l1.fit_transform(House_DF["KitchenQual"])
House_DF["Functional"]=l1.fit_transform(House_DF["Functional"])
House_DF["FireplaceQu"]=l1.fit_transform(House_DF["FireplaceQu"])
House_DF["GarageType"]=l1.fit_transform(House_DF["GarageType"])
House_DF["GarageFinish"]=l1.fit_transform(House_DF["GarageFinish"])
House_DF["GarageQual"]=l1.fit_transform(House_DF["GarageQual"])
House_DF["GarageCond"]=l1.fit_transform(House_DF["GarageCond"])
House_DF["PavedDrive"]=l1.fit_transform(House_DF["PavedDrive"])
House_DF["PoolQC"]=l1.fit_transform(House_DF["PoolQC"])
House_DF["Fence"]=l1.fit_transform(House_DF["Fence"])
House_DF["MiscFeature"]=l1.fit_transform(House_DF["MiscFeature"])
House_DF["SaleType"]=l1.fit_transform(House_DF["SaleType"])
House_DF["SaleCondition"]=l1.fit_transform(House_DF["SaleCondition"])

House_DF.head(10)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         3         65.0     8450       1      1         3
# 1   2          20         3         80.0     9600       1      1         3
# 2   3          60         3         68.0    11250       1      1         0
# 3   4          70         3         60.0     9550       1      1         0
# 4   5          60         3         84.0    14260       1      1         0
# 5   6          50         3         85.0    14115       1      1         0
# 6   7          20         3         75.0    10084       1      1         3
# 7   8          60         3         70.0    10382       1      1         0
# 8   9          50         4         51.0     6120       1      1         3
# 9  10         190         3         50.0     7420       1      1         3
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# ...

# %%
House_DF['GarageYrBlt'] = House_DF['GarageYrBlt'].astype(str)
data1=[]
for x in House_DF["GarageYrBlt"]:
    a1=x[:-2]
    data1.append(a1)

# %%
del House_DF["GarageYrBlt"]
House_DF.insert(59,"GarageYrBlt",data1)
House_DF['GarageYrBlt'] = House_DF['GarageYrBlt'].astype(float)

# %%
House_DF["MasVnrArea"]=House_DF["MasVnrArea"].replace(np.nan,0)
House_DF.replace([np.inf,-np.inf], np.nan, inplace=True)
House_DF.fillna(999, inplace=True)

# %%
x = House_DF.iloc[:,:-1].values
y = House_DF.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
rg=LinearRegression()
rg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
rg.score(X_test, y_test)
# Out:
# 0.548399018295211
